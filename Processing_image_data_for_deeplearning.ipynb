# %% [markdown]
# <a href="https://colab.research.google.com/github/revathichavala/basic/blob/main/Processing_image_data_for_deeplearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget 'https://media.4-paws.org/1/e/d/6/1ed6da75afe37d82757142dc7c6633a532f53a7d/VIER%20PFOTEN_2019-03-15_001-2886x1999-1920x1330.jpg'
# Out:
# --2025-02-22 15:38:13--  https://media.4-paws.org/1/e/d/6/1ed6da75afe37d82757142dc7c6633a532f53a7d/VIER%20PFOTEN_2019-03-15_001-2886x1999-1920x1330.jpg
# Resolving media.4-paws.org (media.4-paws.org)... 116.202.15.201
# Connecting to media.4-paws.org (media.4-paws.org)|116.202.15.201|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 133359 (130K) [image/jpeg]
# Saving to: ‘VIER PFOTEN_2019-03-15_001-2886x1999-1920x1330.jpg’
#
# VIER PFOTEN_2019-03 100%[===================>] 130.23K   351KB/s    in 0.4s
#
# 2025-02-22 15:38:14 (351 KB/s) - ‘VIER PFOTEN_2019-03-15_001-2886x1999-1920x1330.jpg’ saved [133359/133359]

# %% [markdown]
# libraries that can be used for image processing
# 1.matplotlib.image
# 2.pillow
# 3.OpenCV

# %% [markdown]
# # New Section

# %%
#importing the image module from matplotlib library
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
#loading an image through matplotlib.image module
img =mpimg.imread('/content/dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (1330, 1920, 3)

# %%
print(img)
# Out:
# [[[225 228 233]
#   [225 228 233]
#   [225 228 233]
#   ...
#   [160 159 155]
#   [159 158 154]
#   [159 158 154]]
#
#  [[225 228 233]
#   [225 228 233]
#   [225 228 233]
#   ...
#   [159 158 154]
#   [159 158 154]
#   [159 158 154]]
#
#  [[225 228 233]
#   [225 228 233]
#   [225 228 233]
#   ...
#   [158 157 153]
#   [158 157 153]
#   [158 157 153]]
#
#  ...
#
#  [[123 114  57]
#   [124 115  58]
#   [125 116  57]
#   ...
#   [ 97  91  39]
#   [ 98  92  40]
#   [ 98  92  40]]
#
#  [[125 119  61]
#   [125 119  61]
#   [125 119  61]
#   ...
#   [ 97  91  41]
#   [ 97  91  41]
#   [ 98  92  42]]
#
#  [[125 119  61]
#   [125 119  61]
#   [125 119  61]
#   ...
#   [ 97  91  41]
#   [ 97  91  41]
#   [ 98  92  42]]]

# %%
#displaying the image from numpy array
img_plot = plt.imshow(img)
plt.show()

# %% [markdown]
# resizing the image using pillow library

# %%
from PIL import Image

# %%
img = Image.open('/content/dog.jpg')
img_resized = img.resize((200,200))

# %%
img_resized.save('dog_image_resize.jpg')

# %%
img_res =mpimg.imread('/content/dog_image_resize.jpg')
img_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (500, 500, 3)

# %% [markdown]
# coloured(rgb)image to greyscale image uisng open cv

# %%
#imorting opencv library
import cv2

# %%
img = cv2.imread('/content/dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1330, 1920, 3)

# %%
grayscale_image =cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (1330, 1920)

# %% [markdown]
# cv2.imshow() will display the image.But this will not be allowed in google colab.
# from google.colab.patches import cv2_imshow
#
# > **Add blockquote**

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=1920x1330>

# %%
# saving the grayscale image
cv2.imwrite('dog_grayscale_image.jpg',grayscale_image)
# Out:
# True
